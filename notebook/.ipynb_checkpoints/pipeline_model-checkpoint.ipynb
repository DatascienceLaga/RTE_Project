# %% [markdown]
# ## Pipeline de modélisation

# %% [markdown]
# **Context:**
#
# We have built a pipeline allowing to generate Time-Series by the simulator and the reference data in order to create a predictive model. The predictive model is based on a Random Forest model.
# The training dataset is created using positive values from the reference model and simulations. The codes used for this pipeline are available in the script folder or at https://github.com/DatascienceLaga/RTE_Project/tree/dev-nithushan/script
#
# <ol>
# <li> Generation of Time-Series </li>
# <li> Learning set </li>
# <li> Data processing </li>
# <li> Learning algorithm </li>
# <li> Training </li>
# <li> Evaluation </li>
# </ol>
#
#
# The positive values of the simulation (X_train, X_test) and of the reference (y_train, y_test) are recovered with an 80% / 20% split of the data.
# The prediction (y_pred) is then evaluated in comparison with the reference (y_test)

# %% [markdown]
# ## Modules import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import sys
sys.path.append("..")
from uvsw_part import simulation

from script import evaluation
from script import traitement
from script import generation
import copy
from math import e

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

import plotly

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading of the paths to the List * .txt and index files of the reference Time-Series used

# %% [markdown]
# We define here the relative paths leading to the various List.txt files containing the basic parameters of the Time-Series as well as the index of the Time-Series that we use as a reference model

# %%
# Path to list of time series
LIST_PATH_1 = "../data/params/List1.txt"
LIST_PATH_2 = "../data/params/List2.txt"
# Index of time series to simulate
TS_INDEX = 5

# %% [markdown]
# # Launch of the modeling pipeline (Random Forest)

# %% [markdown]
# Generate the Time-Series associated with the parameters as well as a modeling with Random Forest
#
# Arguments:
#
# - h: Parameter h of the simulator
#
# - tension: Simulator tension parameter
#
# - u: Parameter u of the simulator
#
# - clo: Clo parameter of the simulator
#
# - eps: Parameter eps of the simulator
#
# - TS_INDEX: time-series index (starts at 0)
#
# - LIST_PATH: path leading to the List * .txt file
#
# - plot_type: Type of graphical interface with matplotlib or plotly ("plt" or "plotly")
#
#
# Outputs:
#
# - Plot of the time-series with the simulation signal and the reference signal with matplotlib or plotly
#
# - Plot of the prediction signal and the reference signal with matplotlib or plotly

# %%
generation.generation_rforest(h = 309.49288554663354,tension = 11605.8732786244,
                          u = 0.9535838147886668,clo = 0.6,eps = 0.3,
                          TS_INDEX = TS_INDEX,LIST_PATH = LIST_PATH_1, plot_type = "plotly")
# Out:
# Liste_1
# h value:  309.49288554663354  u value:  0.9535838147886668  tension value:  11605.8732786244 clo value  0.6
# tf value  4.0
# ----------------------------------
# Calcul simulation : Début
# Calcul simulation : Terminé
# Processing des données : Terminé
# Entrainement : Terminé
# Evaluation : Terminé
# ...
