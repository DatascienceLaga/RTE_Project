# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml

from uvsw_part import simulation


if __name__ == '__main__':

    cfg = yaml.safe_load(open('example.in.yaml', 'r'))
    dfy, _ = simulation.run_cable_wakeosc(cfg)

    

    plt.figure()
    plt.plot(dfy.index, dfy['s=0.250']/0.025)
    plt.xlabel('time (s)')
    plt.ylabel('y/d')

    plt.show()
# Out:
#  -- running 100.00%

# %%
#compute the max (y/d)
max(dfy['s=0.250']/0.025)
# Out:
# 0.0001738365512230453

# %%
import pandas as pd 
data = {'time':dfy.index,'y/d':dfy['s=0.250']/0.025} # dict object to create dataframe

# %%
data
# Out:
# {'time': Float64Index([                  0.0, 0.0010000000000000002,
#                0.0020000000000000005, 0.0030000000000000005,
#                 0.004000000000000001,  0.005000000000000001,
#                 0.006000000000000001,  0.007000000000000002,
#                 0.008000000000000002,  0.009000000000000003,
#                ...
#                   10.554000000000373,    10.555000000000376,
#                   10.556000000000381,    10.557000000000384,
#                   10.558000000000389,    10.559000000000392,
#                   10.560000000000397,    10.561000000000401,
#                   10.562000000000404,     10.56300000000041],
#               dtype='float64', length=10564),
#  'y/d': 0.000     0.000000e+00
#  0.001     4.116810e-10
#  0.002     1.646432e-09
#  0.003     3.703373e-09
#  0.004     6.581036e-09
#                ...
#  10.559    1.360639e-04
#  10.560    1.394797e-04
#  10.561    1.427995e-04
#  10.562    1.460210e-04
#  10.563    1.491418e-04
#  Name: s=0.250, Length: 10564, dtype: float64}

# %%
DF1_14= pd.DataFrame(data)

# %%
DF1_14
# Out:
#           time           y/d
# 0.000    0.000  0.000000e+00
# 0.001    0.001  4.116810e-10
# 0.002    0.002  1.646432e-09
# 0.003    0.003  3.703373e-09
# 0.004    0.004  6.581036e-09
# ...        ...           ...
# 10.559  10.559  1.360639e-04
# 10.560  10.560  1.394797e-04
# 10.561  10.561  1.427995e-04
# 10.562  10.562  1.460210e-04
# 10.563  10.563  1.491418e-04
#
# [10564 rows x 2 columns]

# %%
DF1_14 = pd.DataFrame(data).to_csv('Liste'+str(1_4)+'.csv',index=False) # Store dataframe on disk for current case

# %%
simulation = pd.read_csv('Liste14.csv')

# %%
ref = pd.read_csv('graph4.csv')

# %%
plt.plot(ref['time'], ref['y/d'])
plt.plot(simulation['time'],simulation['y/d'])
print("------ Timeseries 4 <> U= 0.45  ---------------")
# Out:
# ------ Timeseries 4 <> U= 0.65  ---------------

# %%
ref.head()
# Out:
#    nc  md     U      d     m  L    H     Nt      Dt       tf      ymax  \
# 0   4   1  0.99  0.025  1.57  1  500  26408  0.0004  10.5632  0.000018
# 1   4   1  0.99  0.025  1.57  1  500  26408  0.0004  10.5632  0.000018
# 2   4   1  0.99  0.025  1.57  1  500  26408  0.0004  10.5632  0.000018
# 3   4   1  0.99  0.025  1.57  1  500  26408  0.0004  10.5632  0.000018
# 4   4   1  0.99  0.025  1.57  1  500  26408  0.0004  10.5632  0.000018
#
#      time           y/d
# 0  0.0004 -3.927485e-13
# 1  0.0008 -1.234201e-12
# 2  0.0012 -3.817674e-11
# 3  0.0016 -1.025752e-10
# 4  0.0020 -1.576905e-10
