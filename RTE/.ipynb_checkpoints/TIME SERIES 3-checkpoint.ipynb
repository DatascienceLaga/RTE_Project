# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml

from uvsw_part import simulation


if __name__ == '__main__':

    cfg = yaml.safe_load(open('example.in.yaml', 'r'))
    dfy, _ = simulation.run_cable_wakeosc(cfg)

    sb.heatmap(dfy)

    plt.figure()
    plt.plot(dfy.index, dfy['s=0.250']/0.025)
    plt.xlabel('time (s)')
    plt.ylabel('y/d')

    plt.show()
# Out:
#  -- running 100.00%

# %%
#compute the max (y/d)
max(dfy['s=0.250']/0.025)
# Out:
# 0.00012098215593121479

# %%
import pandas as pd 
data = {'time':dfy.index,'y/d':dfy['s=0.250']/0.025} # dict object to create dataframe

# %%
data
# Out:
# {'time': Float64Index([                  0.0,                 0.001,
#                                0.002, 0.0030000000000000005,
#                 0.003999999999999999, 0.0049999999999999975,
#                 0.005999999999999996,  0.006999999999999995,
#                 0.007999999999999993,  0.008999999999999992,
#                ...
#                   15.218000000012681,    15.219000000012688,
#                   15.220000000012693,      15.2210000000127,
#                   15.222000000012704,     15.22300000001271,
#                   15.224000000012717,    15.225000000012722,
#                   15.226000000012728,    15.227000000012733],
#               dtype='float64', length=15228),
#  'y/d': 0.000     0.000000e+00
#  0.001     4.209068e-12
#  0.002     1.683624e-11
#  0.003     3.788141e-11
#  0.004     6.734442e-11
#                ...
#  15.223    7.883935e-05
#  15.224    7.857170e-05
#  15.225    7.830335e-05
#  15.226    7.803430e-05
#  15.227    7.776456e-05
#  Name: s=0.250, Length: 15228, dtype: float64}

# %%
DF1_13= pd.DataFrame(data)

# %%
DF1_13
# Out:
#           time           y/d
# 0.000    0.000  0.000000e+00
# 0.001    0.001  4.209068e-12
# 0.002    0.002  1.683624e-11
# 0.003    0.003  3.788141e-11
# 0.004    0.004  6.734442e-11
# ...        ...           ...
# 15.223  15.223  7.883935e-05
# 15.224  15.224  7.857170e-05
# 15.225  15.225  7.830335e-05
# 15.226  15.226  7.803430e-05
# 15.227  15.227  7.776456e-05
#
# [15228 rows x 2 columns]

# %%
DF1_13 = pd.DataFrame(data).to_csv('Liste'+str(1_3)+'.csv',index=False) # Store dataframe on disk for current case

# %%
simulation = pd.read_csv('Liste13.csv')

# %%
ref = pd.read_csv('graph3.csv')

# %%
plt.plot(ref['time'], ref['y/d'])
plt.plot(simulation['time'],simulation['y/d'])

# %%
ref.head()
# Out:
#    nc  md     U      d     m  L    H     Nt      Dt       tf      ymax  \
# 0   3   1  0.95  0.025  1.57  1  500  38068  0.0004  15.2272  0.000027
# 1   3   1  0.95  0.025  1.57  1  500  38068  0.0004  15.2272  0.000027
# 2   3   1  0.95  0.025  1.57  1  500  38068  0.0004  15.2272  0.000027
# 3   3   1  0.95  0.025  1.57  1  500  38068  0.0004  15.2272  0.000027
# 4   3   1  0.95  0.025  1.57  1  500  38068  0.0004  15.2272  0.000027
#
#      time           y/d
# 0  0.0004 -3.927635e-13
# 1  0.0008 -1.234365e-12
# 2  0.0012 -3.803724e-11
# 3  0.0016 -1.020456e-10
# 4  0.0020 -1.454415e-10
