# %% [markdown]
# <font color='red'> <h1><center> Valeurs utiles : </h1> </font> || <h2> <center> U = 2.15 || h = 100 || Tension = 32100 </h2>

# %% [markdown]
# <font color='red'> <h1><center> Importation modules </h1> </font>

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml
import numpy as np
from sklearn.metrics import r2_score
from uvsw_part import simulation
from sklearn.metrics import mean_squared_error

import math
from math import e

# %% [markdown]
# <font color='red'> <h1> <center>Chargement fichier config | Verification variables </h1> </font>

# %%
cfg = yaml.safe_load(open('example.in.yaml', 'r'))

# %%
cfg
# Out:
# {'cable': {'type': 'None', 'length': 1.0, 'tension': 32000.0, 'h': 500.0},
#  'conductor': {'m': 1.57, 'd': 0.025, 'EA': 0.0},
#  'simulation': {'ns': 101,
#   'tf': 4.0,
#   'dt': 0.0002,
#   'dr': 0.001,
#   'si': 99,
#   'pp': True},
#  'wakeosc': {'u': 0.9,
#   'st': 0.235,
#   'cl0': 0.6,
#   'eps': 0.3,
#   'al': 0.1,
#   'bt': 0.0,
#   'gm': 0.0,
#   'md': 1,
#   'y0': 0.0,
#   'q0': 0.05}}

# %%
#data_list = pd.read_csv("/home/nithushan/Documents/M2_Stage/RTE/awakosc/uvsw_part/test/List2.txt" , delim_whitespace=True)
data_list = pd.read_csv("List2.txt" , delim_whitespace=True)

data_list.head()
# Out:
#    nc  md  U[m/s]   d[m]  m[kg/m]  L[m]  H[N]      Nt   Dt[s]    tf[s]  \
# 0   1   2    1.86  0.025     1.57     1   500   46556  0.0004  18.6224
# 1   2   2    1.88  0.025     1.57     1   500  100000  0.0004  40.0000
# 2   3   2    1.90  0.025     1.57     1   500  100000  0.0004  40.0000
# 3   4   2    1.92  0.025     1.57     1   500  100000  0.0004  40.0000
# 4   5   2    1.94  0.025     1.57     1   500  100000  0.0004  40.0000
#
#     ymax[m]     filename
# 0  0.000071  Data2.1.bin
# 1  0.001031  Data2.2.bin
# 2  0.001903  Data2.3.bin
# 3  0.001796  Data2.4.bin
# 4  0.000429  Data2.5.bin

# %%
data_list.describe()
# Out:
#               nc    md     U[m/s]          d[m]  m[kg/m]  L[m]         H[N]  \
# count  12.000000  12.0  12.000000  1.200000e+01    12.00  12.0    12.000000
# mean    6.500000   2.0   2.738333  2.500000e-02     1.57   1.0  1125.000000
# std     3.605551   0.0   0.968230  3.623719e-18     0.00   0.0   772.392976
# min     1.000000   2.0   1.860000  2.500000e-02     1.57   1.0   500.000000
# 25%     3.750000   2.0   1.915000  2.500000e-02     1.57   1.0   500.000000
# 50%     6.500000   2.0   2.105000  2.500000e-02     1.57   1.0   500.000000
# 75%     9.250000   2.0   3.822500  2.500000e-02     1.57   1.0  2000.000000
# max    12.000000   2.0   3.860000  2.500000e-02     1.57   1.0  2000.000000
#
#                   Nt      Dt[s]      tf[s]    ymax[m]
# count      12.000000  12.000000  12.000000  12.000000
# mean    76685.416667   0.000317  23.253333   0.000808
# std     34088.685840   0.000103  13.400653   0.000671
# min      4767.000000   0.000200   1.906800   0.000024
# 25%     62288.000000   0.000200  15.034300   0.000174
# 50%    100000.000000   0.000400  20.000000   0.000785
# 75%    100000.000000   0.000400  40.000000   0.001219
# max    100000.000000   0.000400  40.000000   0.001903

# %%
#set_params = data_list.iloc[0,:]
#set_params = data_list.iloc[1,:] # celle de 40

set_params = data_list.iloc[6,:] #celle de 9
#print(set_params["nc"])
#print(data_list.keys())
#print(data_list)
#print(cfg.keys())

# %%
cfg["cable"]["h"] = float(set_params["H[N]"])
cfg["simulation"]["tf"] = float(set_params["tf[s]"])
cfg["wakeosc"]["u"] = float(set_params["U[m/s]"])

# %%
print(cfg)
print("-----")
print(cfg["cable"]["h"])
# Out:
# {'cable': {'type': 'None', 'length': 1.0, 'tension': 32000.0, 'h': 500.0}, 'conductor': {'m': 1.57, 'd': 0.025, 'EA': 0.0}, 'simulation': {'ns': 101, 'tf': 1.9068, 'dt': 0.0002, 'dr': 0.001, 'si': 99, 'pp': True}, 'wakeosc': {'u': 2.23, 'st': 0.235, 'cl0': 0.6, 'eps': 0.3, 'al': 0.1, 'bt': 0.0, 'gm': 0.0, 'md': 1, 'y0': 0.0, 'q0': 0.05}}
# -----
# 500.0

# %%
u_list = np.arange(0.05, 0.5, 0.05)
print(u_list)
# Out:
# [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45]

# %%
ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))
print(ref)
# Out:
#         nc  md     U      d     m  L    H     Nt      Dt       tf      ymax  \
# 0        1   2  1.86  0.025  1.57  1  500  46556  0.0004  18.6224  0.000071
# 1        1   2  1.86  0.025  1.57  1  500  46556  0.0004  18.6224  0.000071
# 2        1   2  1.86  0.025  1.57  1  500  46556  0.0004  18.6224  0.000071
# 3        1   2  1.86  0.025  1.57  1  500  46556  0.0004  18.6224  0.000071
# 4        1   2  1.86  0.025  1.57  1  500  46556  0.0004  18.6224  0.000071
# ...     ..  ..   ...    ...   ... ..  ...    ...     ...      ...       ...
# 949945   7   2  2.23  0.025  1.57  1  500   4767  0.0004   1.9068  0.000024
# 949946   7   2  2.23  0.025  1.57  1  500   4767  0.0004   1.9068  0.000024
# 949947   7   2  2.23  0.025  1.57  1  500   4767  0.0004   1.9068  0.000024
# 949948   7   2  2.23  0.025  1.57  1  500   4767  0.0004   1.9068  0.000024
# 949949   7   2  2.23  0.025  1.57  1  500   4767  0.0004   1.9068  0.000024
#
#           time           y/d
# 0       0.0004 -3.925815e-13
# 1       0.0008 -1.232346e-12
# 2       0.0012 -4.230106e-11
# 3       0.0016 -1.158912e-10
# 4       0.0020 -1.886572e-10
# ...        ...           ...
# 949945  1.9052 -1.330004e-04
# 949946  1.9056 -1.349617e-04
# 949947  1.9060 -1.366788e-04
# 949948  1.9064 -1.381351e-04
# 949949  1.9068 -1.393199e-04
#
# [949950 rows x 13 columns]

# %% [markdown]
# <h1> <center> Test de <u> toutes les séries temporelles </u> avec des valeurs différentes de h </center> </h1>

# %%
h_list = [100]



if __name__ == '__main__':
    for idx, row in data_list.iterrows():
        print("""
        ####################################################################################### 
        #                                      Serie n: {}                                     #
        #######################################################################################
        """.format(set_params["nc"])
        )
        set_params = data_list.iloc[idx,:]
        ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))
        #u_list = np.arange(set_params["U[m/s]"]-set_params["U[m/s]"]/1.05882353, set_params["U[m/s]"]/2, 0.05)
        
        
        #   
        
        for h_value in h_list: 

            print("################ H value: {} ################".format(h_value))
            cfg = yaml.safe_load(open('example.in.yaml', 'r'))
            
            #cfg["cable"]["h"] = float(set_params["H[N]"])
            cfg["cable"]["h"] = float(h_value)
            
            cfg["simulation"]["tf"] = float(set_params["tf[s]"])
            
            #cfg["cable"]["tension"] = float(set_params["H[N]"])
            cfg["cable"]["tension"] = float(32000)
            
            #cfg["wakeosc"]["u"] = float(u_value)
            #cfg["wakeosc"]["u"] = float(set_params["U[m/s]"])
            cfg["wakeosc"]["u"] = 2.15
            
            
            cfg["simulation"]["dt"] = cfg["simulation"]["tf"] / len(ref) # MODIF DT
            cfg["simulation"]["dr"] = cfg["simulation"]["tf"] / len(ref) # MODIF DR
            
            
            print("h value: ", cfg["cable"]["h"], " u value: ", cfg["wakeosc"]["u"])

            dfy, _ = simulation.run_cable_wakeosc(cfg)

            #print(r2_score(ref['y/d'],simulation['y/d'][:-1]))
            #print(mean_squared_error(ref['y/d'],simulation['y/d'][:-1])) # Moi qui ai testé

            plt.figure(figsize = (20,5))
            plt.plot(ref['time'], ref['y/d'], label = "ref")
            plt.plot(dfy.index, dfy['s=0.250']/0.025, label = "sim")
            plt.xlabel('time (s)')
            plt.ylabel('y/d')

            plt.legend()
            plt.show() 
            
            #print(r2_score(ref['y/d'],dfy['s=0.250']/0.025[:-1]))
            #print(mean_squared_error(ref['y/d'],dfy['s=0.250']/0.025[:-1])) # Moi qui ai testé
            
            print("R2 : ",r2_score(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1]))
            print("MSE : ",mean_squared_error(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1])) # Moi qui ai testé

# %% [markdown]
# <h1> <center> Test d'une <u> unique série </u> temporelle avec des valeurs différentes de SI </center> </h1>

# %%
si_list = np.arange(0.05, 1.0, 0.05) # Valeur de tension testée sur la time series en question


#set_params = data_list.iloc[5,:]
set_params = data_list.iloc[0,:] # Permet de selectionner la Time-series sur laquelles on teste les paramètres


ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))

for si_value in si_list: 

    #print("################ si value: {} ################".format(si_value))
    cfg = yaml.safe_load(open('example.in.yaml', 'r'))

    #cfg["cable"]["h"] = float(set_params["H[N]"])
    cfg["cable"]["h"] = 100.

    cfg["simulation"]["tf"] = float(set_params["tf[s]"])

    #cfg["cable"]["tension"] = float(set_params["H[N]"])
    cfg["cable"]["tension"] = 32100.

    #cfg["wakeosc"]["u"] = float(u_value)
    #cfg["wakeosc"]["u"] = float(set_params["U[m/s]"])
    cfg["wakeosc"]["u"] = 2.15
    
    cfg["simulation"]["si"] = si_value


    cfg["simulation"]["dt"] = cfg["simulation"]["tf"] / len(ref) # MODIF DT
    cfg["simulation"]["dr"] = cfg["simulation"]["tf"] / len(ref) # MODIF DR


    print("h value: ", cfg["cable"]["h"], " u value: ", cfg["wakeosc"]["u"],
          " tension value: ",cfg["cable"]["tension"],"si value",cfg["simulation"]["si"])

    dfy, _ = simulation.run_cable_wakeosc(cfg)

    #print(r2_score(ref['y/d'],simulation['y/d'][:-1]))
    #print(mean_squared_error(ref['y/d'],simulation['y/d'][:-1])) # Moi qui ai testé

    plt.figure(figsize = (20,5))
    plt.plot(ref['time'], ref['y/d'], label = "ref")
    plt.plot(dfy.index, dfy['s=0.250']/0.025, label = "sim")
    plt.xlabel('time (s)')
    plt.ylabel('y/d')

    plt.legend()
    plt.show() 

    #print(r2_score(ref['y/d'],dfy['s=0.250']/0.025[:-1]))
    #print(mean_squared_error(ref['y/d'],dfy['s=0.250']/0.025[:-1])) # Moi qui ai testé

    print("R2 : ",r2_score(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1]))
    print("MSE : ",mean_squared_error(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1])) # Moi qui ai testé
# Out:
# h value:  100.0  u value:  2.15  tension value:  32100.0 si value 3
#  -- running  0.72%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-0cea6e645d45> in <module>
#      35           " tension value: ",cfg["cable"]["tension"],"si value",cfg["simulation"]["si"])
#      36
# ---> 37     dfy, _ = simulation.run_cable_wakeosc(cfg)
#      38
#      39     #print(r2_score(ref['y/d'],simulation['y/d'][:-1]))
#
# ~/Documents/M2_Stage/RTE/awakosc/uvsw_part/test/uvsw_part/simulation.py in run_cable_wakeosc(cf)
#      99     y = y0 * np.sin(md * np.pi * s)
#     100     q = q0 * np.sin(md * np.pi * s)
# --> 101     r = cable.solve_wo(cb, pm, wo, shape=(y, None, q), speed=None, fast=True)
#     102
#     103     cl = ['s=%.3f' % (s,) for s in pm.si]
#
# ~/Documents/M2_Stage/RTE/awakosc/uvsw_part/test/uvsw_part/cable.py in solve_wo(cb, pm, wo, shape, speed, remove_cat, fast)
#     398                 q[1:-1] = ht * r[1:-1] + R3
#     399             else:
# --> 400                 Xx = ((I - A44).multiply(1. / (M * ht2)) + Is2) * (I - A21.multiply(ht)) - A41.multiply(ht) - Is3
#     401                 Rs = (A21 * R1 + R2) / M
#     402                 Rx = R4 + A41 * R1 + Rs + (I - A44) * (Rs / ht2 + R3 / ht)
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/base.py in __sub__(self, other)
#     432             if other.shape != self.shape:
#     433                 raise ValueError("inconsistent shapes")
# --> 434             return self._sub_sparse(other)
#     435         elif isdense(other):
#     436             other = np.broadcast_to(other, self.shape)
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/base.py in _sub_sparse(self, other)
#     394
#     395     def _sub_sparse(self, other):
# --> 396         return self.tocsr()._sub_sparse(other)
#     397
#     398     def _sub_dense(self, other):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in _sub_sparse(self, other)
#     361
#     362     def _sub_sparse(self, other):
# --> 363         return self._binopt(other, '_minus_')
#     364
#     365     def multiply(self, other):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in _binopt(self, other, op)
#    1218     def _binopt(self, other, op):
#    1219         """apply the binary operation fn to two sparse matrices."""
# -> 1220         other = self.__class__(other)
#    1221
#    1222         # e.g. csr_plus_csr, csr_minus_csr, etc.
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      32                 arg1 = arg1.copy()
#      33             else:
# ---> 34                 arg1 = arg1.asformat(self.format)
#      35             self._set_self(arg1)
#      36
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/base.py in asformat(self, format, copy)
#     320             # Forward the copy kwarg, if it's accepted.
#     321             try:
# --> 322                 return convert_method(copy=copy)
#     323             except TypeError:
#     324                 return convert_method()
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/base.py in tocsr(self, copy)
#     905         the resultant csr_matrix.
#     906         """
# --> 907         return self.tocoo(copy=copy).tocsr(copy=False)
#     908
#     909     def todok(self, copy=False):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/coo.py in tocsr(self, copy)
#     407                       indptr, indices, data)
#     408
# --> 409             x = csr_matrix((data, indices, indptr), shape=self.shape)
#     410             if not self.has_canonical_format:
#     411                 x.sum_duplicates()
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#     104             self.data = self.data.astype(dtype, copy=False)
#     105
# --> 106         self.check_format(full_check=False)
#     107
#     108     def getnnz(self, axis=None):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in check_format(self, full_check)
#     155                  "".format(self.indices.dtype.name), stacklevel=3)
#     156
# --> 157         idx_dtype = get_index_dtype((self.indptr, self.indices))
#     158         self.indptr = np.asarray(self.indptr, dtype=idx_dtype)
#     159         self.indices = np.asarray(self.indices, dtype=idx_dtype)
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/sputils.py in get_index_dtype(arrays, maxval, check_contents)
#     151     """
#     152
# --> 153     int32min = np.iinfo(np.int32).min
#     154     int32max = np.iinfo(np.int32).max
#     155
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/numpy/core/getlimits.py in __init__(self, int_type)
#     519         self.kind = self.dtype.kind
#     520         self.bits = self.dtype.itemsize * 8
# --> 521         self.key = "%s%d" % (self.kind, self.bits)
#     522         if self.kind not in 'iu':
#     523             raise ValueError("Invalid integer data type %r." % (self.kind,))
#
# KeyboardInterrupt:

# %% [markdown]
# <br> https://gist.github.com/sagarmainkar/41d135a04d7d3bc4098f0664fe20cf3c <br>

# %% [markdown]
# <br> https://towardsdatascience.com/gradient-descent-in-python-a0d07285742f <br>

# %% [markdown]
# <h1> <center> Fonction de coût pour la descente de gradient (MSE) </h1>

# %%
def  cal_cost(prediction,y):
    '''
    
    Calculates the cost for given X and Y. The following shows and example of a single dimensional X
    theta = Vector of thetas 
    X     = Row of X's np.zeros((2,j))
    y     = Actual y's np.zeros((2,1))
    
    where:
        j is the no of features
    '''
    
    m = len(y)
    
    #predictions = X.dot(u)
    #cfg["wakeosc"]["u"] = float(u)
    #dfy, _ = simulation.run_cable_wakeosc(cfg)
    cost = (1/2*m) * np.sum(np.square(prediction-y))
    return cost

# %% [markdown]
# <h1> <center> Algorithme de descente de gradient </h1>

# %%
def descente_gradient(u,learning_rate=0.01,iterations=100):
    ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))
    '''
    X    = Matrix of X with added bias units
    y    = Vector of Y
    theta=Vector of thetas np.random.randn(j,1)
    learning_rate 
    iterations = no of iterations
    
    Returns the final theta vector and array of cost history over no of iterations
    '''
    y = ref['y/d']
    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    
    cfg = yaml.safe_load(open('example.in.yaml', 'r'))
    cfg["cable"]["h"] = float(set_params["H[N]"])
    cfg["simulation"]["tf"] = float(set_params["tf[s]"])
    
    dfy, _ = simulation.run_cable_wakeosc(cfg)
    prediction =  dfy['s=0.250'].values # vecteur numpy
    prediction = np.append(prediction,np.zeros(m - len(prediction)))
    
    
    
    
    
    for it in range(iterations):
        
        #prediction = np.dot(X,u)
        
        
        u= u -(1/m)*learning_rate*( prediction.T.dot((prediction - y))) # 1
        print("-------")
        print("Valeur de u = " + str(u))
        
        cfg = yaml.safe_load(open('example.in.yaml', 'r'))
        cfg["cable"]["h"] = float(set_params["H[N]"])
        cfg["simulation"]["tf"] = float(set_params["tf[s]"])
        cfg["wakeosc"]["u"] = float(u)
        
        dfy, _ = simulation.run_cable_wakeosc(cfg)
        prediction =  dfy['s=0.250']
        prediction = np.append(prediction,np.zeros(m - len(prediction)))
        
        theta_history[it,:] =u.T
        cost_history[it]  = cal_cost(prediction,y)
        print("---------------------------")
        print(cost_history[it])
        
        plt.figure(figsize = (20,5))
        plt.plot(ref['time'], ref['y/d'], label = "ref")
        #plt.plot(dfy.index, dfy['s=0.250']/0.025, label = "sim")
        plt.plot(dfy.index, dfy['s=0.250'], label = "sim")
        plt.xlabel('time (s)')
        plt.ylabel('y/d')

        plt.legend()
        plt.show()
        
    return u, cost_history, theta_history

# %% [markdown]
# <h1> <center>Execution de l'algorithme de descente de gradient </h1>

# %%
lr =0.01
n_iter = 1000
u = 7

#theta = np.random.randn(2,1)

#X_b = np.c_[np.ones((len(X),1)),X]
#theta,cost_history,theta_history = gradient_descent(X,y,theta,lr,n_iter)
theta,cost_history,theta_history = descente_gradient(u,lr,n_iter)


#print('Theta0:          {:0.3f},\nTheta1:          {:0.3f}'.format(theta[0][0],theta[1][0]))
#print('Final cost/MSE:  {:0.3f}'.format(cost_history[-1]))

# %% [markdown]
# <h1> <center> VERSION PERSONNELLE DE LA DESCENTE GRADIENT </h1>

# %%
# MA VERSION DE LA DESCENTE GRADIENT



alpha=0.01

x=0
x_param = x

nbremaxiter=1000
nbiter=0

epsilon=10 ** (- 5)

fprime = 2 *(x - 2)

Grad=fprime # Le gradient
xx=[] # Mémoire des x, Chemin
fx=[] # Memoire des fx

while (nbiter <= nbremaxiter and abs(Grad) > epsilon):

    fprime = 2 *(x - 2)

    fx.append((x-2)**2) # Liste contenant les valeurs de fx


    xx.append(x) # Liste contenant en mémoire les valeurs de x

    x = x - (alpha*Grad)

    Grad= fprime

    nbiter=nbiter + 1
    print("Epsilon = " + str(epsilon) + " || Grad = " + str(Grad) + " || Iter = "  + str(nbiter) + " || X = " + str(x))

print("-----------------------")
print("Options de l'algorithme : Alpha = " + str(alpha) + " || X = " + str(x_param) + " || Iterations = " + str(nbremaxiter))
print("Le minimum trouvé par l'algorithme est donc : " + str(x) + " en " + str(nbiter) + " iterations")
