# %% [markdown]
# <font color='red'> <h1><center> Premiere TS (iloc 0, Liste2): Valeurs utiles : </h1> </font> || <h2> <center> U = 2.15 || h = 100 || Tension = 32100 </h2>

# %% [markdown]
# <font color='red'> <h1><center> Importation modules </h1> </font>

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error
from uvsw_part import simulation
import copy
from math import e

# %% [markdown]
# <font color='red'> <h1> <center>Chargement fichier config | Verification variables </h1> </font>

# %%
data_list = pd.read_csv("List2.txt" , delim_whitespace=True)
data_list.head()
# Out:
#    nc  md  U[m/s]   d[m]  m[kg/m]  L[m]  H[N]      Nt   Dt[s]    tf[s]  \
# 0   1   2    1.86  0.025     1.57     1   500   46556  0.0004  18.6224
# 1   2   2    1.88  0.025     1.57     1   500  100000  0.0004  40.0000
# 2   3   2    1.90  0.025     1.57     1   500  100000  0.0004  40.0000
# 3   4   2    1.92  0.025     1.57     1   500  100000  0.0004  40.0000
# 4   5   2    1.94  0.025     1.57     1   500  100000  0.0004  40.0000
#
#     ymax[m]     filename
# 0  0.000071  Data2.1.bin
# 1  0.001031  Data2.2.bin
# 2  0.001903  Data2.3.bin
# 3  0.001796  Data2.4.bin
# 4  0.000429  Data2.5.bin

# %% [markdown]
# <h1> <center> Test de <u> toutes les séries temporelles </u> avec des valeurs différentes de h </center> </h1>

# %%
def h_test_allts(h_list, tension, u):


    if __name__ == '__main__':
        for idx, row in data_list.iterrows():
            set_params = data_list.iloc[idx,:]
            ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))

            print("""
            ####################################################################################### 
            #                                      Serie n: {}                                     #
            #######################################################################################
            """.format(set_params["nc"])
            )        



            for h_value in h_list: 

                print("################ H value: {} ################".format(h_value))
                cfg = yaml.safe_load(open('example.in.yaml', 'r'))

                
                cfg["cable"]["h"] = float(h_value)

                cfg["simulation"]["tf"] = float(set_params["tf[s]"])

                tension = float(tension)
                cfg["cable"]["tension"] = tension

                cfg["wakeosc"]["u"] = u


                cfg["simulation"]["dt"] = cfg["simulation"]["tf"] / len(ref) # MODIF DT
                cfg["simulation"]["dr"] = cfg["simulation"]["tf"] / len(ref) # MODIF DR


                print("Tension value : ", cfg["cable"]["tension"], " u value: ", cfg["wakeosc"]["u"])

                dfy, _ = simulation.run_cable_wakeosc(cfg)



                plt.figure(figsize = (20,5))
                plt.plot(ref['time'], ref['y/d'], label = "ref")
                plt.plot(dfy.index, dfy['s=0.250']/0.025, label = "sim")
                plt.xlabel('time (s)')
                plt.ylabel('y/d')

                plt.legend()
                plt.show() 

                print("R2 : ",r2_score(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1]))
                print("MSE : ",mean_squared_error(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1])) # Moi qui ai testé

# %%
h_list = [100]
tension = 32100
u = 2.15

h_test_allts(h_list,tension,u)
# Out:
#             #######################################################################################
#             #                                      Serie n: 1                                     #
#             #######################################################################################
#
# ################ H value: 100 ################
# Tension value :  32100.0  u value:  2.15
#  -- running  0.71%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-c0189893629a> in <module>
#       3 u = 2.15
#       4
# ----> 5 h_test_allts(h_list,tension,u)
#
# <ipython-input-41-b51410e6da76> in h_test_allts(h_list, tension, u)
#      38                 print("Tension value : ", cfg["cable"]["tension"], " u value: ", cfg["wakeosc"]["u"])
#      39
# ---> 40                 dfy, _ = simulation.run_cable_wakeosc(cfg)
#      41
#      42
#
# ~/Documents/M2_Stage/RTE/awakosc/uvsw_part/test/uvsw_part/simulation.py in run_cable_wakeosc(cf)
#      99     y = y0 * np.sin(md * np.pi * s)
#     100     q = q0 * np.sin(md * np.pi * s)
# --> 101     r = cable.solve_wo(cb, pm, wo, shape=(y, None, q), speed=None, fast=True)
#     102
#     103     cl = ['s=%.3f' % (s,) for s in pm.si]
#
# ~/Documents/M2_Stage/RTE/awakosc/uvsw_part/test/uvsw_part/cable.py in solve_wo(cb, pm, wo, shape, speed, remove_cat, fast)
#     400                 Xx = ((I - A44).multiply(1. / (M * ht2)) + Is2) * (I - A21.multiply(ht)) - A41.multiply(ht) - Is3
#     401                 Rs = (A21 * R1 + R2) / M
# --> 402                 Rx = R4 + A41 * R1 + Rs + (I - A44) * (Rs / ht2 + R3 / ht)
#     403                 Xb = np.zeros((3, n))
#     404                 Xb[0, +1:] = Xx.diagonal(k=1)
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/base.py in __sub__(self, other)
#     432             if other.shape != self.shape:
#     433                 raise ValueError("inconsistent shapes")
# --> 434             return self._sub_sparse(other)
#     435         elif isdense(other):
#     436             other = np.broadcast_to(other, self.shape)
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/base.py in _sub_sparse(self, other)
#     394
#     395     def _sub_sparse(self, other):
# --> 396         return self.tocsr()._sub_sparse(other)
#     397
#     398     def _sub_dense(self, other):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in _sub_sparse(self, other)
#     361
#     362     def _sub_sparse(self, other):
# --> 363         return self._binopt(other, '_minus_')
#     364
#     365     def multiply(self, other):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in _binopt(self, other, op)
#    1245            indptr, indices, data)
#    1246
# -> 1247         A = self.__class__((data, indices, indptr), shape=self.shape)
#    1248         A.prune()
#    1249
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#     104             self.data = self.data.astype(dtype, copy=False)
#     105
# --> 106         self.check_format(full_check=False)
#     107
#     108     def getnnz(self, axis=None):
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/scipy/sparse/compressed.py in check_format(self, full_check)
#     175         if (len(self.indices) != len(self.data)):
#     176             raise ValueError("indices and data should have the same size")
# --> 177         if (self.indptr[-1] > len(self.indices)):
#     178             raise ValueError("Last value of index pointer should be less than "
#     179                              "the size of index and data arrays")
#
# KeyboardInterrupt:

# %% [markdown]
# <h1> <center> Test d'une <u> unique série </u> temporelle avec des valeurs différentes de Tension </center> </h1>

# %%
def h_test_uniquets(h_list, tension, u, set_params):

    ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))
    tension = float(tension)

    for h_value in h_list: 

        print("################ h value: {} ################".format(h_value))
        cfg = yaml.safe_load(open('example.in.yaml', 'r'))

        #cfg["cable"]["h"] = float(set_params["H[N]"])
        cfg["cable"]["h"] = float(h_value)

        cfg["simulation"]["tf"] = float(set_params["tf[s]"])

        cfg["cable"]["tension"] = tension
        #cfg["cable"]["tension"] = float(T_value)

        #cfg["wakeosc"]["u"] = float(u_value)
        #cfg["wakeosc"]["u"] = float(set_params["U[m/s]"])
        cfg["wakeosc"]["u"] = u

        cfg["simulation"]["dt"] = cfg["simulation"]["tf"] / len(ref) # MODIF DT
        cfg["simulation"]["dr"] = cfg["simulation"]["tf"] / len(ref) # MODIF DR



        print("h value: ", cfg["cable"]["h"], " u value: ", cfg["wakeosc"]["u"]," tension value: ",cfg["cable"]["tension"])

        dfy, _ = simulation.run_cable_wakeosc(cfg)

        #print(r2_score(ref['y/d'],simulation['y/d'][:-1]))
        #print(mean_squared_error(ref['y/d'],simulation['y/d'][:-1])) # Moi qui ai testé

        plt.figure(figsize = (20,5))
        plt.plot(ref['time'], ref['y/d'], label = "ref")
        plt.plot(dfy.index, dfy['s=0.250']/0.025, label = "sim")
        plt.xlabel('time (s)')
        plt.ylabel('y/d')

        plt.legend()
        plt.show() 

        #print(r2_score(ref['y/d'],dfy['s=0.250']/0.025[:-1]))
        #print(mean_squared_error(ref['y/d'],dfy['s=0.250']/0.025[:-1])) # Moi qui ai testé

        print("R2 : ",r2_score(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1]))
        print("MSE : ",mean_squared_error(ref['y/d'],(dfy['s=0.250']/0.025).values[:-1])) # Correct

# %%
h_list = [100] # Valeur de h testée sur la time series en question
tension = 32100
u = 2.15
set_params = data_list.iloc[0,:] # Permet de selectionner la Time-series sur laquelles on teste les paramètres

h_test_uniquets(h_list,tension,u,set_params)

# %%
sim_data = dfy['s=0.250'].iloc[1:,]/0.025
sim_data.head()
# Out:
# 0.0002    3.758634e-10
# 0.0004    1.503209e-09
# 0.0006    3.381305e-09
# 0.0008    6.008923e-09
# 0.0010    9.384345e-09
# Name: s=0.250, dtype: float64

# %%
ref_data = ref.set_index("time").sort_index()['y/d']
ref_data.head(10)
# Out:
# time
# 0.0004   -3.925815e-13
# 0.0004    3.925815e-13
# 0.0008    1.232346e-12
# 0.0008   -1.232346e-12
# 0.0012   -4.230106e-11
# 0.0012    4.229774e-11
# 0.0016   -1.158912e-10
# 0.0016    1.158726e-10
# 0.0020   -1.886572e-10
# 0.0020    1.886209e-10
# Name: y/d, dtype: float64

# %%
sim_ref_data = pd.concat([
    pd.DataFrame(sim_data.values,columns = ["sim"]),
    pd.DataFrame(ref_data.values[ref_data.values >= 0], columns = ["ref_pos"]),
    pd.DataFrame(ref_data.values[ref_data.values < 0], columns = ["ref_neg"])   
],axis = 1)

sim_ref_data.head(50)
# Out:
#              sim       ref_pos       ref_neg
# 0   3.758634e-10  3.925815e-13 -3.925815e-13
# 1   1.503209e-09  1.232346e-12 -1.232346e-12
# 2   3.381305e-09  4.229774e-11 -4.230106e-11
# 3   6.008923e-09  1.158726e-10 -1.158912e-10
# 4   9.384345e-09  1.886209e-10 -1.886572e-10
# 5   1.350535e-08  2.632670e-10 -2.633164e-10
# 6   1.836922e-08  3.527716e-10 -3.528359e-10
# 7   2.397274e-08  4.489687e-10 -4.490489e-10
# 8   3.031217e-08  5.290709e-10 -5.291598e-10
# 9   3.738329e-08  6.096745e-10 -6.097813e-10
# 10  4.518137e-08  6.969391e-10 -6.970723e-10
# 11  5.370115e-08  7.911905e-10 -7.913373e-10
# 12  6.293688e-08  9.048174e-10 -9.049655e-10
# 13  7.288231e-08  1.045455e-09 -1.045611e-09
# 14  8.353067e-08  1.206031e-09 -1.206206e-09
# 15  9.487468e-08  1.353012e-09 -1.353193e-09
# 16  1.069066e-07  1.485432e-09 -1.485610e-09
# 17  1.196180e-07  1.625851e-09 -1.626041e-09
# 18  1.330003e-07  1.781876e-09 -1.782080e-09
# 19  1.470440e-07  1.931816e-09 -1.932030e-09
# 20  1.617395e-07  2.046839e-09 -2.047059e-09
# 21  1.770764e-07  2.020737e-09 -2.020959e-09
# 22  1.930439e-07  1.945723e-09 -1.945962e-09
# 23  2.096308e-07  1.937603e-09 -1.937857e-09
# 24  2.268252e-07  1.920349e-09 -1.920607e-09
# 25  2.446151e-07  1.940246e-09 -1.940508e-09
# 26  2.629875e-07  1.981033e-09 -1.981300e-09
# 27  2.819294e-07  1.965863e-09 -1.966139e-09
# 28  3.014270e-07  1.866959e-09 -1.867242e-09
# 29  3.214662e-07  1.698073e-09 -1.698360e-09
# 30  3.420325e-07  1.513166e-09 -1.513459e-09
# 31  3.631108e-07  1.301614e-09 -1.301911e-09
# 32  3.846855e-07  1.036485e-09 -1.036786e-09
# 33  4.067407e-07  7.734450e-10 -7.737505e-10
# 34  4.292602e-07  6.233851e-10 -6.236937e-10
# 35  4.522270e-07  4.799041e-10 -4.802166e-10
# 36  4.756240e-07  2.838488e-10 -2.841617e-10
# 37  4.994336e-07  2.049972e-10 -2.053095e-10
# 38  5.236377e-07  2.161114e-10 -2.164230e-10
# 39  5.482179e-07  8.088446e-13 -1.116607e-12
# 40  5.731553e-07  4.911289e-10 -4.914273e-10
# 41  5.984310e-07  1.254412e-09 -1.254697e-09
# 42  6.240251e-07  2.082709e-09 -2.082983e-09
# 43  6.499180e-07  3.002235e-09 -3.002496e-09
# 44  6.760893e-07  4.233189e-09 -4.233435e-09
# 45  7.025184e-07  5.484557e-09 -5.484795e-09
# 46  7.291845e-07  6.687900e-09 -6.688134e-09
# 47  7.560663e-07  8.103919e-09 -8.104149e-09
# 48  7.831423e-07  9.669175e-09 -9.669400e-09
# 49  8.103907e-07  1.116501e-08 -1.116522e-08

# %%
sim_ref_data.isna().sum()
# Out:
#          sim  ref_pos  ref_neg
# 0      False    False    False
# 1      False    False    False
# 2      False    False    False
# 3      False    False    False
# 4      False    False    False
# ...      ...      ...      ...
# 93107  False     True     True
# 93108  False     True     True
# 93109  False     True     True
# 93110  False     True     True
# 93111  False     True     True
#
# [93112 rows x 3 columns]

# %%
sim_ref_data.to_csv("sim_ref_data_7.csv", header = True, index = None)

# %%
pd.DataFrame(sim_data.values,columns = ["sim"])
# Out:
#                 sim
# 0      3.758634e-10
# 1      1.503209e-09
# 2      3.381305e-09
# 3      6.008923e-09
# 4      9.384345e-09
# ...             ...
# 93107  1.886795e-03
# 93108  1.855491e-03
# 93109  1.823004e-03
# 93110  1.789356e-03
# 93111  1.754566e-03
#
# [93112 rows x 1 columns]

# %%
#test = ref_data.values
test_pos = ref_data[ref_data > 0]
test_neg = ref_data[ref_data < 0]

# %%
print(test_pos.shape)
print(test_neg.shape)
# Out:
# (46563,)
# (46549,)

# %%
sim_data = pd.DataFrame({"ref":ref['y/d'],"sim":(dfy['s=0.250']/0.025).values[:-1]})
sim_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-e1547d906138> in <module>
# ----> 1 sim_data = pd.DataFrame({"ref":ref['y/d'],"sim":(dfy['s=0.250']/0.025).values[:-1]})
#       2 sim_data.head()
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~/anaconda3/envs/stage/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     413                         f"length {len(index)}"
#     414                     )
# --> 415                     raise ValueError(msg)
#     416             else:
#     417                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 46556 does not match index length 93112

# %%
sim_data.to_csv("sim_data_7.csv", header = True, index = None)

# %% [markdown]
# <br> https://gist.github.com/sagarmainkar/41d135a04d7d3bc4098f0664fe20cf3c <br>

# %% [markdown]
# <br> https://towardsdatascience.com/gradient-descent-in-python-a0d07285742f <br>

# %% [markdown]
# <h1> <center> Fonction de coût pour la descente de gradient (MSE) </h1>

# %%
def  cal_cost(prediction,y):
    '''
    
    Calculates the cost for given X and Y. The following shows and example of a single dimensional X
    theta = Vector of thetas 
    X     = Row of X's np.zeros((2,j))
    y     = Actual y's np.zeros((2,1))
    
    where:
        j is the no of features
    '''
    
    m = len(y)
    
    #predictions = X.dot(u)
    #cfg["wakeosc"]["u"] = float(u)
    #dfy, _ = simulation.run_cable_wakeosc(cfg)
    cost = (1/2*m) * np.sum(np.square(prediction-y))
    return cost

# %% [markdown]
# <h1> <center> Algorithme de descente de gradient </h1>

# %%
def descente_gradient(u,learning_rate=0.01,iterations=100):
    ref = pd.read_csv("graph{}.csv".format(set_params["nc"]))
    '''
    X    = Matrix of X with added bias units
    y    = Vector of Y
    theta=Vector of thetas np.random.randn(j,1)
    learning_rate 
    iterations = no of iterations
    
    Returns the final theta vector and array of cost history over no of iterations
    '''
    y = ref['y/d']
    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    
    cfg = yaml.safe_load(open('example.in.yaml', 'r'))
    cfg["cable"]["h"] = float(set_params["H[N]"])
    cfg["simulation"]["tf"] = float(set_params["tf[s]"])
    
    dfy, _ = simulation.run_cable_wakeosc(cfg)
    prediction =  dfy['s=0.250'].values # vecteur numpy
    prediction = np.append(prediction,np.zeros(m - len(prediction)))
    
    
    
    
    
    for it in range(iterations):
        
        #prediction = np.dot(X,u)
        
        
        u= u -(1/m)*learning_rate*( prediction.T.dot((prediction - y))) # 1
        print("-------")
        print("Valeur de u = " + str(u))
        
        cfg = yaml.safe_load(open('example.in.yaml', 'r'))
        cfg["cable"]["h"] = float(set_params["H[N]"])
        cfg["simulation"]["tf"] = float(set_params["tf[s]"])
        cfg["wakeosc"]["u"] = float(u)
        
        dfy, _ = simulation.run_cable_wakeosc(cfg)
        prediction =  dfy['s=0.250']
        prediction = np.append(prediction,np.zeros(m - len(prediction)))
        
        theta_history[it,:] =u.T
        cost_history[it]  = cal_cost(prediction,y)
        print("---------------------------")
        print(cost_history[it])
        
        plt.figure(figsize = (20,5))
        plt.plot(ref['time'], ref['y/d'], label = "ref")
        #plt.plot(dfy.index, dfy['s=0.250']/0.025, label = "sim")
        plt.plot(dfy.index, dfy['s=0.250'], label = "sim")
        plt.xlabel('time (s)')
        plt.ylabel('y/d')

        plt.legend()
        plt.show()
        
    return u, cost_history, theta_history

# %% [markdown]
# <h1> <center>Execution de l'algorithme de descente de gradient </h1>

# %%
lr =0.01
n_iter = 1000
u = 7

#theta = np.random.randn(2,1)

#X_b = np.c_[np.ones((len(X),1)),X]
#theta,cost_history,theta_history = gradient_descent(X,y,theta,lr,n_iter)
theta,cost_history,theta_history = descente_gradient(u,lr,n_iter)


#print('Theta0:          {:0.3f},\nTheta1:          {:0.3f}'.format(theta[0][0],theta[1][0]))
#print('Final cost/MSE:  {:0.3f}'.format(cost_history[-1]))

# %% [markdown]
# <h1> <center> VERSION PERSONNELLE DE LA DESCENTE GRADIENT </h1>

# %%
# MA VERSION DE LA DESCENTE GRADIENT



alpha=0.01

x=0
x_param = x

nbremaxiter=1000
nbiter=0

epsilon=10 ** (- 5)

fprime = 2 *(x - 2)

Grad=fprime # Le gradient
xx=[] # Mémoire des x, Chemin
fx=[] # Memoire des fx

while (nbiter <= nbremaxiter and abs(Grad) > epsilon):

    fprime = 2 *(x - 2)

    fx.append((x-2)**2) # Liste contenant les valeurs de fx


    xx.append(x) # Liste contenant en mémoire les valeurs de x

    x = x - (alpha*Grad)

    Grad= fprime

    nbiter=nbiter + 1
    print("Epsilon = " + str(epsilon) + " || Grad = " + str(Grad) + " || Iter = "  + str(nbiter) + " || X = " + str(x))

print("-----------------------")
print("Options de l'algorithme : Alpha = " + str(alpha) + " || X = " + str(x_param) + " || Iterations = " + str(nbremaxiter))
print("Le minimum trouvé par l'algorithme est donc : " + str(x) + " en " + str(nbiter) + " iterations")
