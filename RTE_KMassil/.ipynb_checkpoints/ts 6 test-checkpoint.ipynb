# %%
print("------ Timeseries 6 <> U= 0.9  ---------------")


#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml

from uvsw_part import simulation


if __name__ == '__main__':

    cfg = yaml.safe_load(open('example-ts6-1.yaml', 'r'))
    dfy, _ = simulation.run_cable_wakeosc(cfg)

    sb.heatmap(dfy)

    plt.figure()
    plt.plot(dfy.index, dfy['s=0.250']/0.025)
    plt.xlabel('time (s)')
    plt.ylabel('y/d')

    plt.show() 

#compute the max (y/d)
max(dfy['s=0.250']/0.025)


import pandas as pd 
data = {'time':dfy.index,'y/d':dfy['s=0.250']/0.025} # dict object to create dataframe

data

DF1_16= pd.DataFrame(data)

DF1_16

DF1_16 = pd.DataFrame(data).to_csv('Liste'+str(1_6)+'.csv',index=False) # Store dataframe on disk for current case

simulation = pd.read_csv('Liste16.csv')

ref = pd.read_csv('graph6.csv')

plt.plot(ref['time'], ref['y/d'])
plt.plot(simulation['time'],simulation['y/d'])

ref.head()
# Out:
#  -- running 100.00%
#    nc  md      U      d     m  L    H     Nt      Dt  tf      ymax    time  \
# 0   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0004
# 1   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0008
# 2   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0012
# 3   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0016
# 4   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0020
#
#             y/d
# 0 -3.926709e-13
# 1 -1.233349e-12
# 2 -3.928323e-11
# 3 -1.097894e-10
# 4 -1.743938e-10

# %%
print("------ Timeseries 6 <> U= 0.8  ---------------")


#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import yaml

from uvsw_part import simulation


if __name__ == '__main__':

    cfg = yaml.safe_load(open('example-ts6-2.in.yaml', 'r'))
    dfy, _ = simulation.run_cable_wakeosc(cfg)

    sb.heatmap(dfy)

    plt.figure()
    plt.plot(dfy.index, dfy['s=0.250']/0.025)
    plt.xlabel('time (s)')
    plt.ylabel('y/d')

    plt.show() 

#compute the max (y/d)
max(dfy['s=0.250']/0.025)


import pandas as pd 
data = {'time':dfy.index,'y/d':dfy['s=0.250']/0.025} # dict object to create dataframe

data

DF1_16= pd.DataFrame(data)

DF1_16

DF1_16 = pd.DataFrame(data).to_csv('Liste'+str(1_6)+'.csv',index=False) # Store dataframe on disk for current case

simulation = pd.read_csv('Liste16.csv')

ref = pd.read_csv('graph6.csv')

plt.plot(ref['time'], ref['y/d'])
plt.plot(simulation['time'],simulation['y/d'])

ref.head()
# Out:
# ------ Timeseries 6 <> U= 0.8  ---------------
#  -- running 100.00%
#    nc  md      U      d     m  L    H     Nt      Dt  tf      ymax    time  \
# 0   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0004
# 1   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0008
# 2   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0012
# 3   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0016
# 4   6   1  1.265  0.025  1.57  1  500  10000  0.0004   4  0.000003  0.0020
#
#             y/d
# 0 -3.926709e-13
# 1 -1.233349e-12
# 2 -3.928323e-11
# 3 -1.097894e-10
# 4 -1.743938e-10
